# %% [markdown]
# پاکسازی داده ها

# %%
import pandas as pd

# %%
#join

# %%
df = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
                   'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})

# %%
other = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
                      'A': ['B0', 'B1', 'B2']})

# %%
df.join(other, lsuffix='_caller', rsuffix='_other')
# Out:
#   key_caller   A key_other    B
# 0         K0  A0        K0   B0
# 1         K1  A1        K1   B1
# 2         K2  A2        K2   B2
# 3         K3  A3       NaN  NaN
# 4         K4  A4       NaN  NaN
# 5         K5  A5       NaN  NaN

# %%
df.set_index('key').join(other.set_index('key'))
# Out:
#       A    B
# key
# K0   A0   B0
# K1   A1   B1
# K2   A2   B2
# K3   A3  NaN
# K4   A4  NaN
# K5   A5  NaN

# %%
df.join(other.set_index('key'), on='key')
# Out:
#   key   A    B
# 0  K0  A0   B0
# 1  K1  A1   B1
# 2  K2  A2   B2
# 3  K3  A3  NaN
# 4  K4  A4  NaN
# 5  K5  A5  NaN

# %%
d1 = {'Customer_id':pd.Series([1,2,3,4,5,6]),
  'Product':pd.Series(['Oven','Oven','Oven','Television','Television','Television'])}
df1 = pd.DataFrame(d1)

# %%
d2 = {'Customer_id':pd.Series([2,4,6,7,8]),
    'State':pd.Series(['California','California','Texas','New York','Indiana'])}
df2 = pd.DataFrame(d2)

# %%
df1
# Out:
#    Customer_id     Product
# 0            1        Oven
# 1            2        Oven
# 2            3        Oven
# 3            4  Television
# 4            5  Television
# 5            6  Television

# %%
df2
# Out:
#    Customer_id       State
# 0            2  California
# 1            4  California
# 2            6       Texas
# 3            7    New York
# 4            8     Indiana

# %%
inner_join_df= pd.merge(df1, df2, on='Customer_id', how='inner')
inner_join_df
# Out:
#    Customer_id     Product       State
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas

# %%
outer_join_df=pd.merge(df1, df2, on='Customer_id', how='outer')
outer_join_df
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas
# 6            7         NaN    New York
# 7            8         NaN     Indiana

# %%
left_join_df= pd.merge(df1, df2, on='Customer_id', how='left')
left_join_df
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas

# %%
right_join_df= pd.merge(df1, df2, on='Customer_id', how='right')
right_join_df
# Out:
#    Customer_id     Product       State
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas
# 3            7         NaN    New York
# 4            8         NaN     Indiana

# %%
df_row = pd.concat([df1, df2])
df_row
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven         NaN
# 2            3        Oven         NaN
# 3            4  Television         NaN
# 4            5  Television         NaN
# 5            6  Television         NaN
# 0            2         NaN  California
# 1            4         NaN  California
# 2            6         NaN       Texas
# 3            7         NaN    New York
# 4            8         NaN     Indiana

# %%
df_col = pd.concat([df1,df2], axis=1)
df_col
# Out:
#    Customer_id     Product  Customer_id       State
# 0            1        Oven          2.0  California
# 1            2        Oven          4.0  California
# 2            3        Oven          6.0       Texas
# 3            4  Television          7.0    New York
# 4            5  Television          8.0     Indiana
# 5            6  Television          NaN         NaN

# %%
#درک داده ها و توصیف داده ها بوده

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\khorshidsoft\Desktop\data\diabetes.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
data.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# ترسیم های نموادری

# %%
import matplotlib.pyplot as plt

# %%
fig , ax = plt.subplots()
ax.plot(data['Pregnancies'])
plt.show()

# %%
fig , ax = plt.subplots(3,3)
ax[0,0].plot(data['Pregnancies'])
ax[0,1].plot(data['BMI'])
ax[0,2].plot(data['BMI'])
ax[1,0].plot(data['Insulin'])
ax[1,1].plot(data['BloodPressure'])
ax[1,2].plot(data['BloodPressure'])
ax[2,2].plot(data['Insulin'])
plt.show()

# %%
fig , ax = plt.subplots()
ax.plot(data['Pregnancies'])
ax.set_title('Pregnancies')
ax.set_xlabel('num of people')
ax.set_ylabel('Pregnancies')
plt.show()

# %%
#scatter plot

# %%
fig , ax = plt.subplots(figsize=(8, 8))
ax.scatter(data['Insulin'] , data['Age'])
ax.set_xlabel('Insulin')
ax.set_ylabel('Age')
plt.show()

# %%
fig , ax = plt.subplots(figsize=(10, 10))
ax.scatter(data['BMI'] , data['Insulin'] ,c=data['Age'] , s =data['Glucose'] )
ax.set_xlabel('BMI')
ax.set_ylabel('Insulin')
plt.show()

# %%
fig , ax = plt.subplots(figsize=(18, 18))
ax.scatter(data['Insulin'] , data['Age'])
ax.set_xlabel('Insulin')
ax.set_ylabel('Age')
plt.show()

# %% [markdown]
# سوال؟
# پراکندگی داده های مختلف رو نسبت به سن بررسی کنید

# %%
fig , ax = plt.subplots()
ax.hist(data['Insulin'] , rwidth=0.85)
ax.set_xlabel('Insulin')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
fig , ax = plt.subplots(figsize=(10, 10))
ax.hist(data['Age'] , rwidth=0.85)
ax.set_xlabel('Age')
ax.set_ylabel('num fo data')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(data['Age'] , data['BloodPressure'])
ax.set_xlabel('Age')
ax.set_ylabel('BloodPressure')
plt.show()

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
fig , ax = plt.subplots()
ax.boxplot(data['BloodPressure'])
plt.show()

# %%
plt_box = [data['Age'] ,data['BloodPressure'] ,data['Insulin']]
fig , ax = plt.subplots()
ax.boxplot(data['Age']  ,labels=['Age'])
plt.show()

# %%
plt_box = [data['Age'] ,data['BloodPressure'] ,data['Insulin']]
fig , ax = plt.subplots()
ax.boxplot(plt_box ,labels=['Age','BloodPressure','Insulin'])
plt.show()

# %% [markdown]
# سوال لطفا باکس پلات های مختلفی که می توانید رسم کنید با هیستوگرام ها مقایسه کنید و یک تحلیل یک خطی از هر رکورد داده داشته باشید

# %%
import seaborn as sns

# %%
sns.lmplot(x='Age', y='BMI', data=data)

# %%
sns.lmplot(x='BloodPressure', y='Insulin', data=data)

# %%
sns.lmplot(x='BloodPressure', y='Insulin', data=data,
           fit_reg=False, # No regression line
           hue='Outcome')   # Color by evolution stage

# %%
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
fig , ax = plt.subplots(figsize=(12, 12))
sns.boxplot(data=data , ax=ax)
sns.despine()

# %%
sns.violinplot(x='Outcome', y='Insulin', data=data)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Insulin'>

# %% [markdown]
# با استفاده از کتابخانه sns باکس پلات های برای انسولین و فشار خون بکشید

# %%
sns.jointplot(x='BloodPressure', y='Insulin', data=data , kind='reg')

# %%
sns.jointplot(x='BloodPressure', y='Insulin', data=data , kind='hex')

# %%
sns.jointplot(x='BloodPressure', y='Insulin', data=data , kind='kde')

# %%
sns.pairplot(data)

# %%
sns.pairplot(data ,hue='Outcome')

# %%
#برخورد با داده های تکراری و حذف شده

# %%
df = pd.read_csv(r"C:\Users\khorshidsoft\Desktop\data\diabetes_d_n.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               774 non-null    int64
#  1   Glucose                   774 non-null    int64
#  2   BloodPressure             772 non-null    float64
#  3   SkinThickness             770 non-null    float64
#  4   Insulin                   774 non-null    int64
#  5   BMI                       773 non-null    float64
#  6   DiabetesPedigreeFunction  772 non-null    float64
#  7   Age                       770 non-null    float64
#  8   Outcome                   773 non-null    float64
# dtypes: float64(6), int64(3)
# memory usage: 54.5 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   774.000000  774.000000     772.000000     770.000000  774.000000
# mean      3.828165  120.903101      69.044041      20.606494   80.339793
# std       3.364095   31.953146      19.293773      15.956286  115.691306
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   36.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.750000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  773.000000                772.000000  770.000000  773.000000
# mean    31.939327                  0.474635   33.583117    0.350582
# std      7.952324                  0.339241   15.190818    0.477461
# ...

# %%
sns.pairplot(df ,hue='Outcome')

# %%
df_copy = df.copy()

# %%
#راحت ترین کار

# %%
df_copy.dropna(inplace=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 0 to 773
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               760 non-null    int64
#  1   Glucose                   760 non-null    int64
#  2   BloodPressure             760 non-null    float64
#  3   SkinThickness             760 non-null    float64
#  4   Insulin                   760 non-null    int64
#  5   BMI                       760 non-null    float64
#  6   DiabetesPedigreeFunction  760 non-null    float64
#  7   Age                       760 non-null    float64
#  8   Outcome                   760 non-null    float64
# dtypes: float64(6), int64(3)
# memory usage: 59.4 KB

# %%
df_copy.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   760.000000  760.000000     760.000000     760.000000  760.000000
# mean      3.832895  121.015789      68.939474      20.510526   80.344737
# std       3.369588   31.707570      19.391508      15.990112  116.159819
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  760.000000                760.000000  760.000000  760.000000
# mean    31.939079                  0.474889   33.586842    0.353947
# std      7.978718                  0.337874   15.269829    0.478508
# ...

# %%
df_copy
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148           72.0           35.0        0  33.6
# 1              1       85           66.0           29.0        0  26.6
# 2              8      183           64.0            0.0        0  23.3
# 3              1       89           66.0           23.0       94  28.1
# 4              0      137           40.0           35.0      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 769           10      101           76.0           48.0      180  32.9
# 770            2      122           70.0           27.0        0  36.8
# 771            5      121           72.0           23.0      112  26.2
# 772            1      126           60.0            0.0        0  30.1
# 773            1       93           70.0           31.0        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0      1.0
# ...

# %%
df_copy1 = df.copy()

# %%
df_copy1.fillna(0 , inplace=True)

# %%
df_copy1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   774.000000  774.000000     774.000000     774.000000  774.000000
# mean      3.828165  120.903101      68.865633      20.500000   80.339793
# std       3.364095   31.953146      19.585419      15.983477  115.691306
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   36.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.750000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  774.000000                774.000000  774.000000  774.000000
# mean    31.898062                  0.473408   33.409561    0.350129
# std      8.029672                  0.339659   15.341864    0.477319
# ...

# %%
df_copy2 = df.copy()

# %%
df_copy2['BMI']
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 769    32.9
# 770    36.8
# 771    26.2
# 772    30.1
# 773    30.4
# Name: BMI, Length: 774, dtype: float64

# %%
df_copy2['BMI'].fillna(0 ,inplace=True)

# %%
df_copy2.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   774.000000  774.000000     772.000000     770.000000  774.000000
# mean      3.828165  120.903101      69.044041      20.606494   80.339793
# std       3.364095   31.953146      19.293773      15.956286  115.691306
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   36.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.750000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  774.000000                772.000000  770.000000  773.000000
# mean    31.898062                  0.474635   33.583117    0.350582
# std      8.029672                  0.339241   15.190818    0.477461
# ...

# %%
df_copy3 = df.copy()

# %%
mean = df_copy3['BMI'].mean()
median = df_copy3['BMI'].median()
mode = df_copy3['BMI'].mode()

print(mean)
print(median)
print(mode[0])
# Out:
# 31.939327296248358
# 32.0
# 32.0

# %%
print(df_copy3['BloodPressure'].mode()[0])
# Out:
# 70.0

# %%
df_copy2['BMI'].fillna(mean ,inplace=True)

# %% [markdown]
# _____________________________________________________________
# جاهای خالی از داده های دیگر رو با توجه به تحلیلی که در مرحله قبل انجام دادید و بهش رسیدید با یکی از روش های بالا پر کنید
# _____________________________________________________________

# %%
#حذف داده های تکرای

# %%
df_copy1 = df.copy()

# %%
df_copy1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 769    False
# 770    False
# 771    False
# 772    False
# 773    False
# Length: 774, dtype: bool

# %%
print(sum(df_copy1.duplicated()))
# Out:
# 6

# %%
df_copy1.drop_duplicates(inplace=True)

# %%
print(sum(df_copy1.duplicated()))
# Out:
# 0

# %%
df_copy1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     766.000000     764.000000  768.000000
# mean      3.845052  120.894531      69.027415      20.522251   79.799479
# std       3.369578   31.972618      19.312376      15.975022  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  767.000000                766.000000  764.000000  767.000000
# mean    31.989439                  0.472078   33.628272    0.348110
# std      7.888825                  0.331666   15.225196    0.476682
# ...

# %%
df_copy1.dropna(inplace=True)

# %%
df_copy1['Age_day'] = df_copy1['Age'].apply(lambda x :x*365)

# %%
df_copy1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148           72.0           35.0        0  33.6
# 1              1       85           66.0           29.0        0  26.6
# 2              8      183           64.0            0.0        0  23.3
# 3              1       89           66.0           23.0       94  28.1
# 4              0      137           40.0           35.0      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 769           10      101           76.0           48.0      180  32.9
# 770            2      122           70.0           27.0        0  36.8
# 771            5      121           72.0           23.0      112  26.2
# 772            1      126           60.0            0.0        0  30.1
# 773            1       93           70.0           31.0        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome  Age_day
# 0                       0.627  50.0      1.0  18250.0
# ...

# %%
df_copy1.rename(columns={'Age_day':'age per day'})
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148           72.0           35.0        0  33.6
# 1              1       85           66.0           29.0        0  26.6
# 2              8      183           64.0            0.0        0  23.3
# 3              1       89           66.0           23.0       94  28.1
# 4              0      137           40.0           35.0      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 769           10      101           76.0           48.0      180  32.9
# 770            2      122           70.0           27.0        0  36.8
# 771            5      121           72.0           23.0      112  26.2
# 772            1      126           60.0            0.0        0  30.1
# 773            1       93           70.0           31.0        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome  age per day
# ...

# %%
#پیدا کردن داده های پرت

# %%
sns.boxplot(x=df_copy1['Pregnancies'])
# Out:
# <AxesSubplot:xlabel='Pregnancies'>

# %%
sns.boxplot(x=df_copy1['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
#مشخص کردن چارک ها

# %%
df_copy1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   774.000000  774.000000     772.000000     770.000000  774.000000
# mean      3.828165  120.903101      69.044041      20.606494   80.339793
# std       3.364095   31.953146      19.293773      15.956286  115.691306
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   36.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.750000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  773.000000                772.000000  770.000000  773.000000
# mean    31.939327                  0.474635   33.583117    0.350582
# std      7.952324                  0.339241   15.190818    0.477461
# ...

# %%
q1= df_copy1['Age'].quantile(0.25)
q2= df_copy1['Age'].quantile(0.5)
q3= df_copy1['Age'].quantile(0.75)
print(q1)
print(q2)
print(q3)
# Out:
# 24.0
# 29.0
# 41.0

# %%
iqr = q3 - q1
print(iqr)
# Out:
# 17.0

# %%
for i in df_copy1.index:
    if df_copy1.loc[i ,'Age']> (q3 + 1.5*iqr):
        df_copy1.drop(i , inplace=True)

# %%
sns.boxplot(x=df_copy1['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# ______________________________
# شما برای میزان داده های پرت پایین این عمل رو انجام بدید
# ______________________________

# %%
sns.boxplot(x=df_copy1['Pregnancies'])
# Out:
# <AxesSubplot:xlabel='Pregnancies'>

# %%
q1 = df_copy1['Pregnancies'].quantile(0.25)
q3 = df_copy1['Pregnancies'].quantile(0.75)
iqr = q3 - q1
for i in df_copy1.index:
    if df_copy1.loc[i ,'Pregnancies']> (q3 + 1.5*iqr):
        df_copy1.drop(i , inplace=True)

# %%
sns.boxplot(x=df_copy1['Pregnancies'])
# Out:
# <AxesSubplot:xlabel='Pregnancies'>

# %%
df_copy1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   770.000000  770.000000     768.000000     766.000000  770.000000
# mean      3.770130  120.785714      69.036458      20.546997   80.227273
# std       3.273472   31.926884      19.339315      15.971126  115.884001
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   34.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.750000
# max      13.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  769.000000                768.000000  766.000000  769.000000
# mean    31.912744                  0.475031   33.531332    0.347204
# std      7.962225                  0.339561   15.211397    0.476391
# ...
